# %% [markdown]
# <a href="https://colab.research.google.com/github/agnescmafra/IAE285_AULAS/blob/main/OP_ACOMAFRA_AULA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### UNIVERSIDADE FEDERAL DO AMAZONAS
#
#  **INSTITUTO DE EDUCAÇÃO, AGRICULTURA E AMBIENTE**
#
#  CURSO ENGENHARIA AMBIENTAL

# %% [markdown]
# **AULA 3 - OPERAÇÕES UNITÁRIAS**
# ---
# ---
# ---

# %% [markdown]
# **Professora Dra Agnes Cristina Oliveira Mafra**

# %% [markdown]
# **3. BALANÇO DE MASSA COM REAÇÃO**
# ---

# %% [markdown]
# **Tópicos Abordados nesta aula**
# * Equações Químicas;
# * Conservação da Massa com reaçao química;
# * Cálculos de números de mols limitante e excesso;
#
# **Alguns Objetivos de Aprendizagem**
# * Balancear uma equação química.
# * Reconhecer que o número de átomos de cada elemento é conservado em uma reação química.
# * Calcular a composição de saída de um reator químico.

# %% [markdown]
# **Introdução às reações químicas**
# --

# %% [markdown]
# **Assista o vídeo abaixo e acompanhe os exercícios propostos para esta aula escrevendo o conteúdo em seu caderno.**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("MWucuQ-jUT8",560,350,start=0,end=5000,rel=0)

# %% [markdown]
# **Laboratório Virtual de Balanceamento de Equações Químicas**
# ---

# %% [markdown]
# [Laboratório Virtual de Balanceamento de Equações Químicas (PHET)](https://phet.colorado.edu/pt_BR/simulation/balancing-chemical-equations)

# %% [markdown]
# **Clique no link do laboratório virtual e comece pela INTRODUÇÃO.**

# %% [markdown]
# ![Captura de Tela 2021-08-23 às 15.54.30.png](data:image/png;base64,...)

# %% [markdown]
# **Use a ferramenta de balança e faça testes no balanço das reações químicas apresentadas abaixo (Síntese de amônia, Hidrólise e Queima de metado).**

# %% [markdown]
# ![Captura de Tela 2021-08-23 às 15.55.32.png](data:image/png;base64,...)

# %% [markdown]
# **Usando a ferramenta de igualdade e gráfico você também pode verificar suas suposições.**

# %% [markdown]
# ![Captura de Tela 2021-08-23 às 15.55.57.png](data:image/png;base64,...)

# %% [markdown]
# **Vamos usar a opção de JOGOS!!!???** =)

# %% [markdown]
# ![Captura de Tela 2021-08-23 às 15.56.26.png](data:image/png;base64,...)

# %% [markdown]
# **Selecione o seu nível e comece a jogar!!! Confira seus resultados!!**

# %% [markdown]
# ![Captura de Tela 2021-08-23 às 15.56.41.png](data:image/png;base64,...)

# %% [markdown]
# *Não esqueça de nos contar seus resultados!!*

# %% [markdown]
# **Balanço em reatores químicos**
# ---

# %% [markdown]
# **REAGENTE LIMITANTE​**
#
# * Qualquer balanço deve ser calculado em uma Base de Cálculo. Para reações químicas a Base de Cálculo a ser adotada deve estar relacionada ao Reagente Limite. O reagente limite é aquele que aparece em menor proporção em relação à proporção estequiometricamente requerida;
#
# * Os cálculos que envolvem reações químicas, são muitas vezes, facilitados quando realizados em base molar. Contudo, é importante lembrar que o número de mols final não é necessariamente igual ao número total de mols, inicialmente, alimentados à reação;
#
# * Assim sendo, temos que: “A massa global de um sistema é mantida durante uma transformação química”; porém, “o número de mols total de um sistema não é mantido em processos que envolvem reações químicas”.

# %% [markdown]
# **O reagente consumido em primeiro lugar numa reação química é designado reagente limitante. Os outros reagentes dizem-se em excesso.​**

# %% [markdown]
# **DETERMINAÇÃO DO REAGENTE LIMITANTE**
#
# * O “Reagente Limite’’ é aquele que ‘’Limita’’ a reação por esgotar-se antes dos demais reagentes. Ou seja, aquele que se apresenta em uma proporção menor em relação a estequiometria da reação;
#
# * A menor relação entre número de mols alimentados e número de mols estequiométricos (nAl/nest) define o reagente limitante,ou seja, O reagente limitante define a extensão da reação.

# %% [markdown]
# **Exercício Resolvido 1 - A**
# ---

# %% [markdown]
# Se 80,4 Kg.mols de $FeSO_4$, 35,1 Kg.mols de $KMnO_4$ e 135,7 Kg.mols de $H_2SO_4$ são alimentados num reator químico. Qual é o reagente limitante?

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("HGil3aApf7E",560,315,start=0,end=5000,rel=0)

# %% [markdown]
# *Resolução:*
#
# **Passo 1 )** Montar a reação e balancear a equação;
#
# **Passo 2 )** Montar a tabela abaixo com o número de mols estequiométricos e alimentados no processo;
#
# **Passo 3 )** Fazer a razão entre número de mols alimentados e estequiométrico;
#
# **Passo 4 )** Comparar a razão calculada com o número de mols estequiométrico:
#
#
# **Será o reagente LIMITANTE quando a RAZÃO < n_estequiométrico**

# %% [markdown]
# \begin{align*}
# \\10 FeSO_4 + 2 KMnO_4 + 8 H_2SO_4 \Rightarrow 5 Fe_2(SO_4)_3 +2 MnSO_4 + K_2SO_4 + 8 H_2O
# \end{align*}

# %% [markdown]
# | Parâmetros         | | Reagentes  |  |
# | :-------------: | :-----------: | :-----------: | :-----------: |
# |                 | KMnO<sub>4</sub> | H<sub>2</sub>SO<sub>4</sub> |  FeSO<sub>4</sub>
# |n<sub>estequiométrico</sub>  | 2    |  8     |  10       |
# |n<sub>alimentado</sub> | 35.1   | 135.7 |  80.4     |
# |Razão = n<sub>alimentado</sub>/n<sub>estequiométrico</sub> | 17.6  | 17    |  **8.04**    |

# %% [markdown]
# **Você notou que o reagente $FeSO_4$ apresentou a razão 8.04, que é menor que o $n_{estequiométrico}$ de 10 mols?? Portanto, o $FeSO_4$ é o reagente LIMITANTE!!**

# %% [markdown]
# **DETERMINAÇÃO DO REAGENTE EM EXCESSO**
#
# * O percentual de excesso é calculado através da razão entre a "sobra" de reagente e o que reagiu;
#
# \begin{align*}
# \\Excesso_A=\frac{{n}_{alimentadoA}-{n}_{reageA}}{{m}_{reageA}}\\
# \end{align*}

# %% [markdown]
# **Exercício Resolvido 1 - B**
# ---

# %% [markdown]
# Qual a % em excesso do $FeSO_4$ e $H_2SO_4$ no exemplo anterior?​

# %% [markdown]
# *Resolução*
#
# *Continuando os Passos:*
#
# **Passo 5 )** Calcular o número de mols total de reagem efetivamente no sistema, ou seja, se há um limitante é este que irá "mandar" nos cálculos!!
#
# **Passo 6 )** Calcular conforme a fórmula o percentual de excesso de cada reagente, lembrando que não há excesso no reagente limitante;
#
# **Passo 7 )** Coloque todos os valores na tabela para facilitar a sua visualização.

# %% [markdown]
# | Parâmetros         | | Reagentes  |  |
# | :-------------: | :-----------: | :-----------: | :-----------: |
# |                 | KMnO<sub>4</sub> | H<sub>2</sub>SO<sub>4</sub> |  FeSO<sub>4</sub>
# |n<sub>estequiométrico</sub>  | 2    |  8     |  10       |
# |n<sub>alimentado</sub> | 35.1   | 135.7 |  80.4     |
# |Razão = n<sub>alimentado</sub>/n<sub>estequiométrico</sub> | 17.6  | 17    |  **8.04**    |
# | n<sub>reage</sub>| 16.1| 64.3 | **80.4** |
# | Excesso(%)| 118| 111 | 0 |

# %% [markdown]
# *Os cálculos do termo reage são realizados da seguinte maneira:*
#
# * Como o limitante é o $FeSO_4$ o valor do alimentado é igual ao termo reage.
# * Faz-se a regra de três :
#
# \begin{align*}
# \\8 mols de H_2SO_4  \Longleftrightarrow  10 mols de FeSO_4\\
# \\x mols de H_2SO_4 \Longleftrightarrow  80.4 mols de FeSO_4\\
# \end{align*}

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
import math
x = Symbol ('x')
sol1 = solve (10*x-80.4*8,x)
print('Nreage de H2SO4 =', sol1)
# Out:
# Nreage de H2SO4 = [64.3200000000000]

# %% [markdown]
# \begin{align*}
# \\2 mols de KMnO_4  \Longleftrightarrow  10 mols de FeSO_4\\
# \\x mols de KMnO_4  \Longleftrightarrow  80.4 mols de FeSO_4\\
# \end{align*}

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
x = Symbol ('x')
sol2 = solve (10*x-80.4*2,x)
print('Nreage de KMnO4 =', sol2)
# Out:
# Nreage de KMnO4 = [16.0800000000000]

# %% [markdown]
# Cálculo dos Excessos:

# %%
Excesso_H2SO4 = 100*(135.7-64.3)/64.3
print(Excesso_H2SO4)
# Out:
# 111.04199066874027

# %%
Excesso_KMnO4 = 100*(35.1-16.1)/16.1
print(Excesso_KMnO4)
# Out:
# 118.01242236024844

# %% [markdown]
# **Você coneguiu compreender? Refaça o cálculo dos percentuais à mão!!! Para a sua completa compreensão.**

# %% [markdown]
# **Exercício Resolvido 1 - C**
# ---

# %% [markdown]
# Quanto será a composição dos produtos, considerando exemplo
# anterior?

# %% [markdown]
# \begin{align*}
# \\10 FeSO_4 + 2 KMnO_4 + 8 H_2SO_4 \Rightarrow 5 Fe_2(SO_4)_3 +2 MnSO_4 + K_2SO_4 + 8 H_2O
# \end{align*}

# %% [markdown]
# **Equação Geral**
#
# ***ENTRA - SAI + GERADO - CONSUMO = ACÚMULO***
#
# Para os REAGENTES : SAI = ENTRA - CONSUMO
#
# Para os PRODUTOS : SAI = ENTRA + REAGE

# %% [markdown]
# * Vamos fazer os cálculos para os reagentes primeiro ???

# %%
#Para os REAGENTES : SAI = ENTRA - CONSUMO

#N_final_KMnO4 = N_alimentado_KMnO4 - N_reage_KMnO4
N_final_KMnO4 = 35.1 - 16.1
print('N_final_KMnO4 =', N_final_KMnO4)

#N_final_H2SO4 = N_alimentado_H2SO4 - N_reage_H2SO4
N_final_H2SO4 = 135.7 - 64.3
print('N_final_H2SO4 =',N_final_H2SO4)

#N_final_FeSO4 = N_alimentado_FeSO4 - N_reage_FeSO4
N_final_FeSO4 = 80.4 - 80.4
print('N_final_FeSO4 =',N_final_FeSO4)
# Out:
# N_final_KMnO4 = 19.0
# N_final_H2SO4 = 71.39999999999999
# N_final_FeSO4 = 0.0

# %% [markdown]
# | Parâmetros         | | Reagentes  |  |
# | :-------------: | :-----------: | :-----------: | :-----------: |
# |                 | KMnO<sub>4</sub> | H<sub>2</sub>SO<sub>4</sub> |  FeSO<sub>4</sub>
# |n<sub>estequiométrico</sub>  | 2    |  8     |  10       |
# |n<sub>alimentado</sub> | 35.1   | 135.7 |  80.4     |
# |Razão = n<sub>alimentado</sub>/n<sub>estequiométrico</sub> | 17.6  | 17    |  **8.04**    |
# | n<sub>reage</sub>| 16.1| 64.3 | **80.4** |
# | Excesso(%)| 118| 111 | 0 |
# | n<sub>final</sub>| 19.0| 71.4 | **0.0** |

# %% [markdown]
# * Agora vamos fazer os cálculos para os produtos!

# %% [markdown]
# Bom!! Se você pensar que todo o reagente limitante reagiu efetivamente então, podemos fazer os cálculos das quantidades de produtos formados.

# %% [markdown]
# | Parâmetros         | | Reagentes  | | |  |  Produtos  |  |   |
# | :-------------: | :-----------: | :-----------: | :-----------: | :-----------:  |:-----------: | :-----------:  | :-----------:  |:-----------: |
# |                 | KMnO<sub>4</sub> | H<sub>2</sub>SO<sub>4</sub> |  FeSO<sub>4</sub> | **----------->** | Fe<sub>2</sub>(SO<sub>4</sub>)<sub>3</sub>  |MnSO<sub>4</sub> | K<sub>2</sub>SO<sub>4</sub>  | H<sub>2</sub> |
# |n<sub>estequiométrico</sub>  | 2    |  8     |  10  | | 5 |2 | 1 | 8 |
# |n<sub>alimentado</sub> | 35.1   | 135.7 |  80.4   |  | 0 | 0 | 0 | 0 |
# |Razão = n<sub>alimentado</sub>/n<sub>estequiométrico</sub> | 17.6  | 17  |  **8.04**  | | 0 | 0 | 0 | 0 |
# | n<sub>reage</sub>| 16.1| 64.3 | **80.4** | | 40.2 | 16.1 | 8.0 | 64.3 |
# | Excesso(%)| 118| 111 | 0 | |  0 | 0 | 0 | 0 |
# | n<sub>final</sub>| 19.0| 71.4 | **0.0** |  | 40.2 | 16.1 | 8.0 | 64.3 |

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
x = Symbol ('x')
sol3 = solve (10*x-80.4*5,x)
print('N_reage de Fe2(SO4)3 =', sol3)
# Out:
# N_reage de Fe2(SO4)3 = [40.2000000000000]

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
x = Symbol ('x')
sol4 = solve (10*x-80.4*2,x)
print('N_reage de MnSO4 =', sol4)
# Out:
# N_reage de MnSO4 = [16.0800000000000]

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
x = Symbol ('x')
sol5 = solve (10*x-80.4*1,x)
print('N_reage de K2SO4 =', sol5)
# Out:
# N_reage de K2SO4 = [8.04000000000000]

# %%
import sympy
from sympy.solvers import solve
from sympy import Symbol
x = Symbol ('x')
sol6 = solve (10*x-80.4*8,x)
print('N_reage de H2 =', sol6)
# Out:
# N_reage de H2 = [64.3200000000000]

# %% [markdown]
# **Para os produtos N_reage = N_final**

# %% [markdown]
# **Exercício Proposto 1:**
# ---

# %% [markdown]
# *Abra um novo notebook Colab e resolva o exercício proposto.*

# %% [markdown]
# Um reator é alimentado com 105 Kg.mols de $H_2O_2$, 37 Kg.mols de $KMnO_4$ e 500 Kg.mols de $H_2SO_4$.
#
# \begin{align*}
# \\5 H_2O_2 + 2 KMnO_4 + 3 H_2SO_4 \Rightarrow 5 O_2 +2 MnSO_4 + K_2SO_4 + 8 H_2O
# \end{align*}
#
#
#
# a) Determine qual o reagente limitante.
#
# b) Determine a porcentagem em excesso dos demais reagentes.
#
# c) Calcule quantos Kg.mols de $O_2$ serão produzidos.

# %% [markdown]
# **Gabarito:**
# ---

# %% [markdown]
# a) KMnO4
#
# b) H2O2 = 13.5% ; H2SO4 = 800.1%
#
# c) 92.5 Kg.mols de O2

# %% [markdown]
# **Referências Bibliográficas e Leituras Complementares**:
# ---
#
#
# [BADINO & CRUZ, 2017](http://livresaber.sead.ufscar.br:8080/jspui/bitstream/123456789/2682/1/EA_Baldino%26Cruz_MassaEnergiaProcessosQuimicos.pdf)
#
#
# [Notas Jupyter jckantor](https://nbviewer.jupyter.org/github/jckantor/CBE20255/blob/master/notebooks/01.01-Units-and-Engineering-Calculations.ipynb)
#
# [Notas de aula BM_Com reação](https://pt.slideshare.net/neoson/aula-13-balano-de-massa-prof-nelson-area-1-290411)
#
# [PHET - LAB VIRTUAL](https://phet.colorado.edu/pt_BR/)
